# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def F(n):
    if n <= 1:
        return 0
    if n > 1 and n%2!=0:
        return F(n-1) + 3*n**2
    if n > 1 and n%2==0:
        return n//2+F(n-1)+2
    
# F(3) = F(2) + 27 = 1 + F(1) + 2 + 27 = 1 + 0 + 2 + 27 = 30
a = F(49)
print(a)

# %% [markdown]
# ![image.png](attachment:image.png)
