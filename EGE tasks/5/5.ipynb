# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for N in range(1,1000):
    a = ''
    x = N
    while x!=0:
        a = a + str(x%2)
        x = x//2
    a = a[::-1]
    s = a.count('1') %2
    a = a + str(s)
    s = a.count('1') %2
    a = a + str(s)
    r = int(a, 2)
    if r>77:
        print(N)
        break
# Out:
# 19

# %%
a = 15

b=''
while a!=0:
    b = b + str(a%2)
    a = a // 2
b = b[::-1]
print(b)


a = 1467
c = bin(a)[2::1]
print(c)
# Out:
# 1111
# 0b10110111011

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for a in range(100,1000):
    z = ''
    a = str(a)
    s = int(a[0]) + int(a[1])
    x = int(a[1]) + int(a[2])
    if s>x:
        z = str(x) + str(s)
    else:
        z = str(s) + str(x)
    if int(z) == 1115:
        print(a)
        break
# Out:
# 296

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for N in range(100,100000000000000000):
    s = str(N)
    b = []
    for i in range(0, len(s) - 2):
        a = s[i:i+3]
        b.append(int(a))
    # while len(s) != 2:
    #     b.append(int(s[0:3]))
    #     s = s[1:]
    m = min(b)
    mx = max(b)
    z = mx - m
    if z == 623:
        print(N)
        break
# Out:
# 1803
