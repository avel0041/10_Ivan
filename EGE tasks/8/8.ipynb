# %%
from itertools import *
words = list(product('АБВГД', repeat=4))
print(words)
words = list(permutations('ААААББББ', r=4))
print(words)
# Out:
# [('А', 'А', 'А', 'А'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'А', 'В'), ('А', 'А', 'А', 'Г'), ('А', 'А', 'А', 'Д'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'В'), ('А', 'А', 'Б', 'Г'), ('А', 'А', 'Б', 'Д'), ('А', 'А', 'В', 'А'), ('А', 'А', 'В', 'Б'), ('А', 'А', 'В', 'В'), ('А', 'А', 'В', 'Г'), ('А', 'А', 'В', 'Д'), ('А', 'А', 'Г', 'А'), ('А', 'А', 'Г', 'Б'), ('А', 'А', 'Г', 'В'), ('А', 'А', 'Г', 'Г'), ('А', 'А', 'Г', 'Д'), ('А', 'А', 'Д', 'А'), ('А', 'А', 'Д', 'Б'), ('А', 'А', 'Д', 'В'), ('А', 'А', 'Д', 'Г'), ('А', 'А', 'Д', 'Д'), ('А', 'Б', 'А', 'А'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'В'), ('А', 'Б', 'А', 'Г'), ('А', 'Б', 'А', 'Д'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'Б'), ('А', 'Б', 'Б', 'В'), ('А', 'Б', 'Б', 'Г'), ('А', 'Б', 'Б', 'Д'), ('А', 'Б', 'В', 'А'), ('А', 'Б', 'В', 'Б'), ('А', 'Б', 'В', 'В'), ('А', 'Б', 'В', 'Г'), ('А', 'Б', 'В', 'Д'), ('А', 'Б', 'Г', 'А'), ('А', 'Б', 'Г', 'Б'), ('А', 'Б', 'Г', 'В'), ('А', 'Б', 'Г', 'Г'), ('А', 'Б', 'Г', 'Д'), ('А', 'Б', 'Д', 'А'), ('А', 'Б', 'Д', 'Б'), ('А', 'Б', 'Д', 'В'), ('А', 'Б', 'Д', 'Г'), ('А', 'Б', 'Д', 'Д'), ('А', 'В', 'А', 'А'), ('А', 'В', 'А', 'Б'), ('А', 'В', 'А', 'В'), ('А', 'В', 'А', 'Г'), ('А', 'В', 'А', 'Д'), ('А', 'В', 'Б', 'А'), ('А', 'В', 'Б', 'Б'), ('А', 'В', 'Б', 'В'), ('А', 'В', 'Б', 'Г'), ('А', 'В', 'Б', 'Д'), ('А', 'В', 'В', 'А'), ('А', 'В', 'В', 'Б'), ('А', 'В', 'В', 'В'), ('А', 'В', 'В', 'Г'), ('А', 'В', 'В', 'Д'), ('А', 'В', 'Г', 'А'), ('А', 'В', 'Г', 'Б'), ('А', 'В', 'Г', 'В'), ('А', 'В', 'Г', 'Г'), ('А', 'В', 'Г', 'Д'), ('А', 'В', 'Д', 'А'), ('А', 'В', 'Д', 'Б'), ('А', 'В', 'Д', 'В'), ('А', 'В', 'Д', 'Г'), ('А', 'В', 'Д', 'Д'), ('А', 'Г', 'А', 'А'), ('А', 'Г', 'А', 'Б'), ('А', 'Г', 'А', 'В'), ('А', 'Г', 'А', 'Г'), ('А', 'Г', 'А', 'Д'), ('А', 'Г', 'Б', 'А'), ('А', 'Г', 'Б', 'Б'), ('А', 'Г', 'Б', 'В'), ('А', 'Г', 'Б', 'Г'), ('А', 'Г', 'Б', 'Д'), ('А', 'Г', 'В', 'А'), ('А', 'Г', 'В', 'Б'), ('А', 'Г', 'В', 'В'), ('А', 'Г', 'В', 'Г'), ('А', 'Г', 'В', 'Д'), ('А', 'Г', 'Г', 'А'), ('А', 'Г', 'Г', 'Б'), ('А', 'Г', 'Г', 'В'), ('А', 'Г', 'Г', 'Г'), ('А', 'Г', 'Г', 'Д'), ('А', 'Г', 'Д', 'А'), ('А', 'Г', 'Д', 'Б'), ('А', 'Г', 'Д', 'В'), ('А', 'Г', 'Д', 'Г'), ('А', 'Г', 'Д', 'Д'), ('А', 'Д', 'А', 'А'), ('А', 'Д', 'А', 'Б'), ('А', 'Д', 'А', 'В'), ('А', 'Д', 'А', 'Г'), ('А', 'Д', 'А', 'Д'), ('А', 'Д', 'Б', 'А'), ('А', 'Д', 'Б', 'Б'), ('А', 'Д', 'Б', 'В'), ('А', 'Д', 'Б', 'Г'), ('А', 'Д', 'Б', 'Д'), ('А', 'Д', 'В', 'А'), ('А', 'Д', 'В', 'Б'), ('А', 'Д', 'В', 'В'), ('А', 'Д', 'В', 'Г'), ('А', 'Д', 'В', 'Д'), ('А', 'Д', 'Г', 'А'), ('А', 'Д', 'Г', 'Б'), ('А', 'Д', 'Г', 'В'), ('А', 'Д', 'Г', 'Г'), ('А', 'Д', 'Г', 'Д'), ('А', 'Д', 'Д', 'А'), ('А', 'Д', 'Д', 'Б'), ('А', 'Д', 'Д', 'В'), ('А', 'Д', 'Д', 'Г'), ('А', 'Д', 'Д', 'Д'), ('Б', 'А', 'А', 'А'), ('Б', 'А', 'А', 'Б'), ('Б', 'А', 'А', 'В'), ('Б', 'А', 'А', 'Г'), ('Б', 'А', 'А', 'Д'), ('Б', 'А', 'Б', 'А'), ('Б', 'А', 'Б', 'Б'), ('Б', 'А', 'Б', 'В'), ('Б', 'А', 'Б', 'Г'), ('Б', 'А', 'Б', 'Д'), ('Б', 'А', 'В', 'А'), ('Б', 'А', 'В', 'Б'), ('Б', 'А', 'В', 'В'), ('Б', 'А', 'В', 'Г'), ('Б', 'А', 'В', 'Д'), ('Б', 'А', 'Г', 'А'), ('Б', 'А', 'Г', 'Б'), ('Б', 'А', 'Г', 'В'), ('Б', 'А', 'Г', 'Г'), ('Б', 'А', 'Г', 'Д'), ('Б', 'А', 'Д', 'А'), ('Б', 'А', 'Д', 'Б'), ('Б', 'А', 'Д', 'В'), ('Б', 'А', 'Д', 'Г'), ('Б', 'А', 'Д', 'Д'), ('Б', 'Б', 'А', 'А'), ('Б', 'Б', 'А', 'Б'), ('Б', 'Б', 'А', 'В'), ('Б', 'Б', 'А', 'Г'), ('Б', 'Б', 'А', 'Д'), ('Б', 'Б', 'Б', 'А'), ('Б', 'Б', 'Б', 'Б'), ('Б', 'Б', 'Б', 'В'), ('Б', 'Б', 'Б', 'Г'), ('Б', 'Б', 'Б', 'Д'), ('Б', 'Б', 'В', 'А'), ('Б', 'Б', 'В', 'Б'), ('Б', 'Б', 'В', 'В'), ('Б', 'Б', 'В', 'Г'), ('Б', 'Б', 'В', 'Д'), ('Б', 'Б', 'Г', 'А'), ('Б', 'Б', 'Г', 'Б'), ('Б', 'Б', 'Г', 'В'), ('Б', 'Б', 'Г', 'Г'), ('Б', 'Б', 'Г', 'Д'), ('Б', 'Б', 'Д', 'А'), ('Б', 'Б', 'Д', 'Б'), ('Б', 'Б', 'Д', 'В'), ('Б', 'Б', 'Д', 'Г'), ('Б', 'Б', 'Д', 'Д'), ('Б', 'В', 'А', 'А'), ('Б', 'В', 'А', 'Б'), ('Б', 'В', 'А', 'В'), ('Б', 'В', 'А', 'Г'), ('Б', 'В', 'А', 'Д'), ('Б', 'В', 'Б', 'А'), ('Б', 'В', 'Б', ' ...
# [('А', 'А', 'А', 'А'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'А', 'А'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'А', 'А'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'А', 'А'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'А', 'А'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'А', 'А'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'А', 'Б'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'А'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'А', 'Б', 'Б'), ('А', 'Б', 'А', 'А'), ('А', 'Б', 'А', 'А'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'А'), ('А', 'Б', 'А', 'А'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'А'), ('А', 'Б', 'А', 'А'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'Б'), ('А', 'Б', 'Б', 'Б'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'Б'), ('А', 'Б', 'Б', 'Б'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'Б'), ('А', 'Б', 'Б', 'Б'), ('А', 'Б', 'А', 'А'), ('А', 'Б', 'А', 'А'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'А'), ('А', 'Б', 'А', 'А'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'А'), ('А', 'Б', 'А', 'А'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'Б'), ('А', 'Б', 'Б', 'Б'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'Б'), ('А', 'Б', 'Б', 'Б'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'Б'), ('А', 'Б', 'Б', 'Б'), ('А', 'Б', 'А', 'А'), ('А', 'Б', 'А', 'А'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'А'), ('А', 'Б', 'А', 'А'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'А'), ('А', 'Б', 'А', 'А'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'А', 'Б'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'Б'), ('А', 'Б', 'Б', 'Б'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'Б'), ('А', 'Б', 'Б', 'Б'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'А'), ('А', 'Б', 'Б', 'Б'), ('А', 'Б', 'Б', 'Б'), ('А', 'Б', 'А', 'А'), ('А', 'Б', 'А', ' ...

# %% [markdown]
# Все 4-⁠буквенные слова, составленные из букв В, Л, Т, У, записаны в алфавитном порядке и пронумерованы.
#
# Вот начало списка:
#
# 1.  ВВВВ
#
# 2.  ВВВЛ
#
# 3.  ВВВТ
#
# 4.  ВВВУ
#
# ...
#
#
#
# Запишите слово, которое стоит под номером 75.

# %%
from itertools import *
words = list (product('ВЛТУ', repeat = 4))
print(words[74])
# Out:
# ('2', '1', '3', '3')

# %% [markdown]
# Шифр кодового замка представляет собой последовательность из пяти символов, каждый из которых является цифрой от 1 до 4. Сколько различных вариантов шифра можно задать, если известно, что цифра 1 встречается ровно два раза, а каждая из других допустимых цифр может встречаться в шифре любое количество раз или не встречаться совсем?

# %%
q = 0
from itertools import *
s = list (product('1234', repeat = 5))
for el in s:
    if el.count('1') == 2:
        q += 1
print(q)
# Out:
# 270

# %% [markdown]
# Михаил составляет 5-⁠буквенные коды. В кодах разрешается использовать только буквы А, Б, В, Г, Д, при этом код не может начинаться с гласной и не может содержать двух одинаковых букв подряд. Сколько различных кодов может составить Михаил?

# %%
from itertools import *
s = list(product('АБВГД', repeat = 5))
q = 0
for el in s:
    if not(el[0] == 'А'):                         # el[0] in ['Б', 'В', ...]
        f = 0
        for i in range(0, len(el)-1):
            if el[i] == el[i+1]:
                f = 1
                break
        if f == 0:
            q += 1
print(q)
# Out:
# 1024

# %% [markdown]
# Алиса составляет 6-⁠буквенные слова из букв М, А, Н, Г, У, С, Т. Каждая из букв может встречаться сколько угодно раз, причём первой буквой не может быть А, буква У должна встречаться не менее 1 раза. Также в записи должны быть ровно две буквы М.
#
# Сколько различных слов может составить Алиса?

# %%
# Out:
# 9155

# %% [markdown]
# Определите количество восьмизначных 15-⁠ричных чисел, в записи которых ровно два нуля и не более четырёх цифр, для записи которых используются буквы.

# %%
from itertools import*
s = list(product('01A', repeat = 8))
q = 0
for el in s:
    if el.count('0') == 2 and el[0] != '0':
        if el.count('A') <= 4:
            q += 5 ** el.count('A') * 9 ** el.count('1')
print(q)
# Out:
# 154248381

# %% [markdown]
# Сколько существует различных четырёхзначных чисел, записанных в семеричной системе счисления, в записи которых цифры следуют слева направо в строго убывающем порядке?

# %%
# Out:
# 35

# %% [markdown]
# Найдите количество пятизначных восьмеричных чисел, в которых все цифры различны и никакие две четные или нечетные не стоят рядом.

# %%
from itertools import *
s = list(permutations('01234567', r=5))
q = 0
for el in s:
    f = 0
    if el[0] == '0':
        f = 1
    for i in range(0,4):
        if int(el[i])%2 == int(el[i+1])%2:
            f = 1
    if f == 0:
        q += 1
print(q)
# Out:
# 504

# %% [markdown]
# Алфавит = {А, Б, В, Т, О, М}
# Сколько слов в которых содержится слово ТОМ?

# %%
# Out:
# 0.03333333333333333
